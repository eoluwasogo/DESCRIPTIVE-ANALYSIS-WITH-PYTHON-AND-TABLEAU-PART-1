# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot
import seaborn as sns

# %%
df= pd.read_csv("/Users/abiodun/Downloads/auto.csv")

# %%
df
# Out:
#      3    ?  alfa-romero     gas    std   two  convertible  rwd  front   88.6  \
# 0    3    ?  alfa-romero     gas    std   two  convertible  rwd  front   88.6
# 1    1    ?  alfa-romero     gas    std   two    hatchback  rwd  front   94.5
# 2    2  164         audi     gas    std  four        sedan  fwd  front   99.8
# 3    2  164         audi     gas    std  four        sedan  4wd  front   99.4
# 4    2    ?         audi     gas    std   two        sedan  fwd  front   99.8
# ..  ..  ...          ...     ...    ...   ...          ...  ...    ...    ...
# 199 -1   95        volvo     gas    std  four        sedan  rwd  front  109.1
# 200 -1   95        volvo     gas  turbo  four        sedan  rwd  front  109.1
# 201 -1   95        volvo     gas    std  four        sedan  rwd  front  109.1
# 202 -1   95        volvo  diesel  turbo  four        sedan  rwd  front  109.1
# 203 -1   95        volvo     gas  turbo  four        sedan  rwd  front  109.1
#
# ...

# %%
headers = ["symbol","normali-loss","make","fuel","aspirnt", "doors","body",
         "wheels","eng-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "no-cylinders", "engine-size","fuel-system","bore","stroke","compresn-ratio","horse-power",
         "rpm","c-mpg","h-mpg","price"]

# %%
df.columns = headers

# %%
df
# Out:
#      symbol normali-loss         make    fuel aspirnt doors         body  \
# 0         3            ?  alfa-romero     gas     std   two  convertible
# 1         1            ?  alfa-romero     gas     std   two    hatchback
# 2         2          164         audi     gas     std  four        sedan
# 3         2          164         audi     gas     std  four        sedan
# 4         2            ?         audi     gas     std   two        sedan
# ..      ...          ...          ...     ...     ...   ...          ...
# 199      -1           95        volvo     gas     std  four        sedan
# 200      -1           95        volvo     gas   turbo  four        sedan
# 201      -1           95        volvo     gas     std  four        sedan
# 202      -1           95        volvo  diesel   turbo  four        sedan
# 203      -1           95        volvo     gas   turbo  four        sedan
#
#     wheels eng-location  wheel-base  ...  engine-size  fuel-system  bore  \
# ...

# %%
df.describe()
# Out:
#            symbol  wheel-base      length       width      height  \
# count  204.000000  204.000000  204.000000  204.000000  204.000000
# mean     0.823529   98.806373  174.075000   65.916667   53.749020
# std      1.239035    5.994144   12.362123    2.146716    2.424901
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.075000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.200000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compresn-ratio       c-mpg       h-mpg
# count   204.000000   204.000000      204.000000  204.000000  204.000000
# mean   2555.602941   126.892157       10.148137   25.240196   30.769608
# std     521.960820    41.744569        3.981000    6.551513    6.898337
# min    1488.000000    61.000000        7.000000   13.000000   16.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   symbol          204 non-null    int64
#  1   normali-loss    204 non-null    object
#  2   make            204 non-null    object
#  3   fuel            204 non-null    object
#  4   aspirnt         204 non-null    object
#  5   doors           204 non-null    object
#  6   body            204 non-null    object
#  7   wheels          204 non-null    object
#  8   eng-location    204 non-null    object
#  9   wheel-base      204 non-null    float64
#  10  length          204 non-null    float64
#  11  width           204 non-null    float64
#  12  height          204 non-null    float64
#  13  curb-weight     204 non-null    int64
#  14  engine-type     204 non-null    object
#  15  no-cylinders    204 non-null    object
#  16  engine-size     204 non-null    int64
# ...

# %%
df.head(7)
# Out:
#    symbol normali-loss         make fuel aspirnt doors         body wheels  \
# 0       3            ?  alfa-romero  gas     std   two  convertible    rwd
# 1       1            ?  alfa-romero  gas     std   two    hatchback    rwd
# 2       2          164         audi  gas     std  four        sedan    fwd
# 3       2          164         audi  gas     std  four        sedan    4wd
# 4       2            ?         audi  gas     std   two        sedan    fwd
# 5       1          158         audi  gas     std  four        sedan    fwd
# 6       1            ?         audi  gas     std  four        wagon    fwd
#
#   eng-location  wheel-base  ...  engine-size  fuel-system  bore  stroke  \
# 0        front        88.6  ...          130         mpfi  3.47    2.68
# 1        front        94.5  ...          152         mpfi  2.68    3.47
# 2        front        99.8  ...          109         mpfi  3.19    3.40
# 3        front        99.4  ...          136         mpfi  3.19    3.40
# ...

# %%
df.tail()
# Out:
#      symbol normali-loss   make    fuel aspirnt doors   body wheels  \
# 199      -1           95  volvo     gas     std  four  sedan    rwd
# 200      -1           95  volvo     gas   turbo  four  sedan    rwd
# 201      -1           95  volvo     gas     std  four  sedan    rwd
# 202      -1           95  volvo  diesel   turbo  four  sedan    rwd
# 203      -1           95  volvo     gas   turbo  four  sedan    rwd
#
#     eng-location  wheel-base  ...  engine-size  fuel-system  bore  stroke  \
# 199        front       109.1  ...          141         mpfi  3.78    3.15
# 200        front       109.1  ...          141         mpfi  3.78    3.15
# 201        front       109.1  ...          173         mpfi  3.58    2.87
# 202        front       109.1  ...          145          idi  3.01    3.40
# 203        front       109.1  ...          141         mpfi  3.78    3.15
#
#     compresn-ratio horse-power   rpm c-mpg h-mpg  price
# ...

# %%
df.replace('?',np.NaN, inplace = True)

# %%
df
# Out:
#      symbol normali-loss         make    fuel aspirnt doors         body  \
# 0         3          NaN  alfa-romero     gas     std   two  convertible
# 1         1          NaN  alfa-romero     gas     std   two    hatchback
# 2         2          164         audi     gas     std  four        sedan
# 3         2          164         audi     gas     std  four        sedan
# 4         2          NaN         audi     gas     std   two        sedan
# ..      ...          ...          ...     ...     ...   ...          ...
# 199      -1           95        volvo     gas     std  four        sedan
# 200      -1           95        volvo     gas   turbo  four        sedan
# 201      -1           95        volvo     gas     std  four        sedan
# 202      -1           95        volvo  diesel   turbo  four        sedan
# 203      -1           95        volvo     gas   turbo  four        sedan
#
#     wheels eng-location  wheel-base  ...  engine-size  fuel-system  bore  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   symbol          204 non-null    int64
#  1   normali-loss    164 non-null    object
#  2   make            204 non-null    object
#  3   fuel            204 non-null    object
#  4   aspirnt         204 non-null    object
#  5   doors           202 non-null    object
#  6   body            204 non-null    object
#  7   wheels          204 non-null    object
#  8   eng-location    204 non-null    object
#  9   wheel-base      204 non-null    float64
#  10  length          204 non-null    float64
#  11  width           204 non-null    float64
#  12  height          204 non-null    float64
#  13  curb-weight     204 non-null    int64
#  14  engine-type     204 non-null    object
#  15  no-cylinders    204 non-null    object
#  16  engine-size     204 non-null    int64
# ...

# %%
df.dropna(subset = 'price', axis = 0, inplace = True)

# %%
df
# Out:
#      symbol normali-loss         make    fuel aspirnt doors         body  \
# 0         3          NaN  alfa-romero     gas     std   two  convertible
# 1         1          NaN  alfa-romero     gas     std   two    hatchback
# 2         2          164         audi     gas     std  four        sedan
# 3         2          164         audi     gas     std  four        sedan
# 4         2          NaN         audi     gas     std   two        sedan
# ..      ...          ...          ...     ...     ...   ...          ...
# 199      -1           95        volvo     gas     std  four        sedan
# 200      -1           95        volvo     gas   turbo  four        sedan
# 201      -1           95        volvo     gas     std  four        sedan
# 202      -1           95        volvo  diesel   turbo  four        sedan
# 203      -1           95        volvo     gas   turbo  four        sedan
#
#     wheels eng-location  wheel-base  ...  engine-size  fuel-system  bore  \
# ...

# %%
rfm_mean = df["rpm"].astype("float").mean(axis = 0)
df["rpm"].replace(np.NaN,rfm_mean, inplace = True)

# %%
bore_mean = df["bore"].astype("float").mean(axis = 0)
df["bore"].replace(np.NaN,bore_mean, inplace = True)

# %%
stroke_mean = df["stroke"].astype("float").mean(axis = 0)
df["stroke"].replace(np.NaN,stroke_mean, inplace = True)

# %%
horse_mean = df["horse-power"].astype("float").mean(axis = 0)
df["horse-power"].replace(np.NaN,horse_mean, inplace = True)

# %%
norm_mean = df["normali-loss"].astype("float").mean(axis = 0)
df["normali-loss"].replace(np.NaN,norm_mean, inplace = True)

# %%
df.isnull().sum()
# Out:
# symbol            0
# normali-loss      0
# make              0
# fuel              0
# aspirnt           0
# doors             2
# body              0
# wheels            0
# eng-location      0
# wheel-base        0
# length            0
# width             0
# height            0
# curb-weight       0
# engine-type       0
# no-cylinders      0
# engine-size       0
# fuel-system       0
# bore              0
# stroke            0
# compresn-ratio    0
# horse-power       0
# rpm               0
# c-mpg             0
# h-mpg             0
# price             0
# dtype: int64

# %%
df['doors'].value_counts()
# Out:
# four    113
# two      85
# Name: doors, dtype: int64

# %%
df['doors'].replace(np.NaN,'four', inplace = True)

# %%
df.isnull().sum()
# Out:
# symbol            0
# normali-loss      0
# make              0
# fuel              0
# aspirnt           0
# doors             0
# body              0
# wheels            0
# eng-location      0
# wheel-base        0
# length            0
# width             0
# height            0
# curb-weight       0
# engine-type       0
# no-cylinders      0
# engine-size       0
# fuel-system       0
# bore              0
# stroke            0
# compresn-ratio    0
# horse-power       0
# rpm               0
# c-mpg             0
# h-mpg             0
# price             0
# dtype: int64

# %%
df.dtypes
# Out:
# symbol              int64
# normali-loss       object
# make               object
# fuel               object
# aspirnt            object
# doors              object
# body               object
# wheels             object
# eng-location       object
# wheel-base        float64
# length            float64
# width             float64
# height            float64
# curb-weight         int64
# engine-type        object
# no-cylinders       object
# engine-size         int64
# fuel-system        object
# bore               object
# stroke             object
# compresn-ratio    float64
# horse-power        object
# rpm                object
# c-mpg               int64
# h-mpg               int64
# price              object
# dtype: object

# %%
df['normali-loss'] = df['normali-loss'].astype("float")
df['price'] = df['price'].astype("float")
df[['rpm','horse-power','stroke','bore']] = df[['price','horse-power','stroke','bore']].astype("float")

# %%
df.dtypes
# Out:
# symbol              int64
# normali-loss      float64
# make               object
# fuel               object
# aspirnt            object
# doors              object
# body               object
# wheels             object
# eng-location       object
# wheel-base        float64
# length            float64
# width             float64
# height            float64
# curb-weight         int64
# engine-type        object
# no-cylinders       object
# engine-size         int64
# fuel-system        object
# bore              float64
# stroke            float64
# compresn-ratio    float64
# horse-power       float64
# rpm               float64
# c-mpg               int64
# h-mpg               int64
# price             float64
# dtype: object

# %%
df
# Out:
#      symbol  normali-loss         make    fuel aspirnt doors         body  \
# 0         3         122.0  alfa-romero     gas     std   two  convertible
# 1         1         122.0  alfa-romero     gas     std   two    hatchback
# 2         2         164.0         audi     gas     std  four        sedan
# 3         2         164.0         audi     gas     std  four        sedan
# 4         2         122.0         audi     gas     std   two        sedan
# ..      ...           ...          ...     ...     ...   ...          ...
# 199      -1          95.0        volvo     gas     std  four        sedan
# 200      -1          95.0        volvo     gas   turbo  four        sedan
# 201      -1          95.0        volvo     gas     std  four        sedan
# 202      -1          95.0        volvo  diesel   turbo  four        sedan
# 203      -1          95.0        volvo     gas   turbo  four        sedan
#
#     wheels eng-location  wheel-base  ...  engine-size  fuel-system  bore  \
# ...

# %%
df['c-mpg']=235/df['c-mpg']

# %%
df['h-mpg']=235/df['h-mpg']

# %%
df.rename(columns= {'c-mpg':'city-l/km'}, inplace = True)
df.rename(columns= {'h-mpg':'high_way - l/km'}, inplace = True)

# %%
df
# Out:
#      symbol  normali-loss         make    fuel aspirnt doors         body  \
# 0         3         122.0  alfa-romero     gas     std   two  convertible
# 1         1         122.0  alfa-romero     gas     std   two    hatchback
# 2         2         164.0         audi     gas     std  four        sedan
# 3         2         164.0         audi     gas     std  four        sedan
# 4         2         122.0         audi     gas     std   two        sedan
# ..      ...           ...          ...     ...     ...   ...          ...
# 199      -1          95.0        volvo     gas     std  four        sedan
# 200      -1          95.0        volvo     gas   turbo  four        sedan
# 201      -1          95.0        volvo     gas     std  four        sedan
# 202      -1          95.0        volvo  diesel   turbo  four        sedan
# 203      -1          95.0        volvo     gas   turbo  four        sedan
#
#     wheels eng-location  wheel-base  ...  engine-size  fuel-system  bore  \
# ...

# %%
df.reset_index(drop = True)
# Out:
#      symbol  normali-loss         make    fuel aspirnt doors         body  \
# 0         3         122.0  alfa-romero     gas     std   two  convertible
# 1         1         122.0  alfa-romero     gas     std   two    hatchback
# 2         2         164.0         audi     gas     std  four        sedan
# 3         2         164.0         audi     gas     std  four        sedan
# 4         2         122.0         audi     gas     std   two        sedan
# ..      ...           ...          ...     ...     ...   ...          ...
# 195      -1          95.0        volvo     gas     std  four        sedan
# 196      -1          95.0        volvo     gas   turbo  four        sedan
# 197      -1          95.0        volvo     gas     std  four        sedan
# 198      -1          95.0        volvo  diesel   turbo  four        sedan
# 199      -1          95.0        volvo     gas   turbo  four        sedan
#
#     wheels eng-location  wheel-base  ...  engine-size  fuel-system  bore  \
# ...

# %%
df.to_csv("/Users/abiodun/Downloads/portfolio1.csv")
